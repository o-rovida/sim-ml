# %%
import numpy as np
from pathlib import Path
import duckdb
import pandas as pd

from categoria_cid import CategoriaCID10
from tools import logger_basic_conf, drop_cols_by_null_percent

logger = logger_basic_conf()

# %%
DATA_DIR = "./data/"
data_path = Path(DATA_DIR)

# %%
CID_10_SUBCAT_FILE = "CID-10-SUBCATEGORIAS.CSV"
CID_10_CAT_FILE = "CID-10-CATEGORIAS.CSV"
CID_10_GRUPOS_FILE = "CID-10-GRUPOS.CSV"
CID_10_CAPITULOS_FILE = "CID-10-CAPITULOS.CSV"

df_cid_subcat = pd.read_csv(data_path / CID_10_SUBCAT_FILE, encoding="latin-1", sep=";")
df_cid_subcat["CAT"] = df_cid_subcat["SUBCAT"].str[:3].astype(str)

df_cid_cat = pd.read_csv(data_path / CID_10_CAT_FILE, encoding="latin-1", sep=";")
df_cid_cat["CAT"] = df_cid_cat["CAT"].astype(str)

df_cid = pd.merge(
    df_cid_subcat, df_cid_cat, on="CAT", how="inner", suffixes=("_SUBCAT", "_CAT")
)

df_cid_grupos = pd.read_csv(data_path / CID_10_GRUPOS_FILE, encoding="latin-1", sep=";")
df_cid_capitulos = pd.read_csv(
    data_path / CID_10_CAPITULOS_FILE, encoding="latin-1", sep=";"
)

df_cid["CAT_OBJ"] = df_cid["CAT"].apply(CategoriaCID10)

df_cid_grupos["CATINIC_OBJ"] = df_cid_grupos["CATINIC"].apply(CategoriaCID10)
df_cid_grupos["CATFIM_OBJ"] = df_cid_grupos["CATFIM"].apply(CategoriaCID10)

df_cid_capitulos["CATINIC_OBJ"] = df_cid_capitulos["CATINIC"].apply(CategoriaCID10)
df_cid_capitulos["CATFIM_OBJ"] = df_cid_capitulos["CATFIM"].apply(CategoriaCID10)


def find_interval(cat_obj, df_interval, start_col, end_col, label_col):
    for _, row in df_interval.iterrows():
        if row[start_col] <= cat_obj <= row[end_col]:
            return row[label_col]
    return None


df_cid["GRUPO"] = df_cid["CAT_OBJ"].apply(
    lambda x: find_interval(x, df_cid_grupos, "CATINIC_OBJ", "CATFIM_OBJ", "DESCRICAO")
)
df_cid["CAPITULO"] = df_cid["CAT_OBJ"].apply(
    lambda x: find_interval(
        x, df_cid_capitulos, "CATINIC_OBJ", "CATFIM_OBJ", "DESCRICAO"
    )
)

# %%
df_cid = drop_cols_by_null_percent(df_cid, null_limit=1, logger=logger)
df_cid = df_cid.drop(columns="CAT_OBJ")

df_cid
# Out:
# 2025-10-27 18:20:06 - INFO - SUBCAT 0.00% nulos < limite 100.00%: APROVADO
# 2025-10-27 18:20:06 - INFO - CLASSIF_SUBCAT 96.96% nulos < limite 100.00%: APROVADO
# 2025-10-27 18:20:06 - INFO - RESTRSEXO 92.98% nulos < limite 100.00%: APROVADO
# 2025-10-27 18:20:06 - INFO - CAUSAOBITO 89.63% nulos < limite 100.00%: APROVADO
# 2025-10-27 18:20:06 - INFO - DESCRICAO_SUBCAT 0.00% nulos < limite 100.00%: APROVADO
# 2025-10-27 18:20:06 - INFO - DESCRABREV_SUBCAT 0.00% nulos < limite 100.00%: APROVADO
# 2025-10-27 18:20:06 - INFO - REFER_SUBCAT 98.74% nulos < limite 100.00%: APROVADO
# 2025-10-27 18:20:06 - INFO - EXCLUIDOS_SUBCAT 99.87% nulos < limite 100.00%: APROVADO
# 2025-10-27 18:20:06 - WARNING - Unnamed: 8 100.00% nulos >= limite 100.00% REPROVADO
# 2025-10-27 18:20:06 - INFO - CAT 0.00% nulos < limite 100.00%: APROVADO
# 2025-10-27 18:20:06 - INFO - CLASSIF_CAT 97.55% nulos < limite 100.00%: APROVADO
# 2025-10-27 18:20:06 - INFO - DESCRICAO_CAT 0.00% nulos < limite 100.00%: APROVADO
# 2025-10-27 18:20:06 - INFO - DESCRABREV_CAT 0.00% nulos < limite 100.00%: APROVADO
# 2025-10-27 18:20:06 - INFO - REFER_CAT 99.88% nulos < limite 100.00%: APROVADO
# 2025-10-27 18:20:06 - WARNING - EXCLUIDOS_CAT 100.00% nulos >= limite 100.00% REPROVADO
# 2025-10-27 18:20:06 - WARNING - Unnamed: 6 100.00% nulos >= limite 100.00% REPROVADO
# 2025-10-27 18:20:06 - INFO - CAT_OBJ 0.00% nulos < limite 100.00%: APROVADO
# 2025-10-27 18:20:06 - INFO - GRUPO 0.00% nulos < limite 100.00%: APROVADO
# 2025-10-27 18:20:06 - INFO - CAPITULO 0.00% nulos < limite 100.00%: APROVADO
#       SUBCAT CLASSIF_SUBCAT RESTRSEXO CAUSAOBITO  \
# 0       A000            NaN       NaN        NaN
# 1       A001            NaN       NaN        NaN
# 2       A009            NaN       NaN        NaN
# 3       A010            NaN       NaN        NaN
# 4       A011            NaN       NaN        NaN
# ...      ...            ...       ...        ...
# 12446   U818            NaN       NaN        NaN
# 12447    U88            NaN       NaN        NaN
# 12448   U898            NaN       NaN        NaN
# 12449   U899            NaN       NaN        NaN
# 12450    U99            NaN       NaN        NaN
#
#                                         DESCRICAO_SUBCAT  \
# 0      Cólera devida a Vibrio cholerae 01, biótipo ch...
# 1      Cólera devida a Vibrio cholerae 01, biótipo El...
# 2                                Cólera não especificada
# 3                                          Febre tifóide
# 4                                    Febre paratifóide A
# ...                                                  ...
# 12446  Agente resistente a outros antibióticos relaci...
# 12447         Agente resistente a múltiplos antibióticos
# 12448  Agente resistente a outro antibiótico especifi...
# 12449   Agente resistente a antibiótico não especificado
# 12450                     CID 10ª Revisão não disponível
#
#                                        DESCRABREV_SUBCAT REFER_SUBCAT  \
# 0      A00.0 Colera dev Vibrio cholerae 01 biot cholerae          NaN
# 1        A00.1 Colera dev Vibrio cholerae 01 biot El Tor          NaN
# 2                                        A00.9 Colera NE          NaN
# 3                                    A01.0 Febre tifoide          NaN
# 4                              A01.1 Febre paratifoide A          NaN
# ...                                                  ...          ...
# 12446  U81.8 Agente resist outr antibiót relac vancom...          NaN
# 12447   U88   Agente resistente a múltiplos antibióticos          NaN
# 12448  U89.8 Agente resist outro antibiótico espec único          NaN
# 12449           U89.9 Agente resistente a antibiótico NE          NaN
# 12450               U99   CID 10a Revisao nao disponivel          NaN
#
#       EXCLUIDOS_SUBCAT  CAT CLASSIF_CAT  \
# 0                  NaN  A00         NaN
# 1                  NaN  A00         NaN
# 2                  NaN  A00         NaN
# 3                  NaN  A01         NaN
# 4                  NaN  A01         NaN
# ...                ...  ...         ...
# 12446              NaN  U81         NaN
# 12447              NaN  U88         NaN
# 12448              NaN  U89         NaN
# 12449              NaN  U89         NaN
# 12450              NaN  U99         NaN
#
#                                            DESCRICAO_CAT  \
# 0                                                 Cólera
# 1                                                 Cólera
# 2                                                 Cólera
# 3                           Febres tifóide e paratifóide
# 4                           Febres tifóide e paratifóide
# ...                                                  ...
# 12446  Agente resistente à vancomicina e antibióticos...
# 12447         Agente resistente a múltiplos antibióticos
# 12448  Agente resistente a outros antibióticos e a an...
# 12449  Agente resistente a outros antibióticos e a an...
# 12450                     CID 10ª Revisão não disponível
#
#                                          DESCRABREV_CAT REFER_CAT  \
# 0                                          A00   Colera       NaN
# 1                                          A00   Colera       NaN
# 2                                          A00   Colera       NaN
# 3                    A01   Febres tifoide e paratifoide       NaN
# 4                    A01   Febres tifoide e paratifoide       NaN
# ...                                                 ...       ...
# 12446  U81   Agente resist vancomicina e antibiót relac       NaN
# 12447  U88   Agente resistente a múltiplos antibióticos       NaN
# 12448   U89   Agente resist outr antibiót e antibiót NE       NaN
# 12449   U89   Agente resist outr antibiót e antibiót NE       NaN
# 12450              U99   CID 10a Revisao nao disponivel       NaN
#
#                                                 GRUPO  \
# 0                     Doenças infecciosas intestinais
# 1                     Doenças infecciosas intestinais
# 2                     Doenças infecciosas intestinais
# 3                     Doenças infecciosas intestinais
# 4                     Doenças infecciosas intestinais
# ...                                               ...
# 12446  Agentes bacterianos resistentes a antibióticos
# 12447  Agentes bacterianos resistentes a antibióticos
# 12448  Agentes bacterianos resistentes a antibióticos
# 12449  Agentes bacterianos resistentes a antibióticos
# 12450                  CID 10ª Revisão não disponível
#
#                                                 CAPITULO
# 0      Capítulo I - Algumas doenças infecciosas e par...
# 1      Capítulo I - Algumas doenças infecciosas e par...
# 2      Capítulo I - Algumas doenças infecciosas e par...
# 3      Capítulo I - Algumas doenças infecciosas e par...
# 4      Capítulo I - Algumas doenças infecciosas e par...
# ...                                                  ...
# 12446  Capítulo XXII - Códigos para propósitos especiais
# 12447  Capítulo XXII - Códigos para propósitos especiais
# 12448  Capítulo XXII - Códigos para propósitos especiais
# 12449  Capítulo XXII - Códigos para propósitos especiais
# 12450  Capítulo XXII - Códigos para propósitos especiais
#
# [12451 rows x 15 columns]

# %%
cid_dict_subcategoria = {
    code: {
        "cid_subcategoria": cid_subcategoria,
        "cid_categoria": cid_categoria,
        "cid_grupo": cid_grupo,
        "cid_capitulo": cid_capitulo,
    }
    for code, cid_subcategoria, cid_categoria, cid_grupo, cid_capitulo in zip(
        df_cid["SUBCAT"],
        df_cid["DESCRICAO_SUBCAT"],
        df_cid["DESCRICAO_CAT"],
        df_cid["GRUPO"],
        df_cid["CAPITULO"],
    )
}

cid_dict_categoria = {
    code: {
        "cid_categoria": cid_categoria,
        "cid_grupo": cid_grupo,
        "cid_capitulo": cid_capitulo,
    }
    for code, cid_categoria, cid_grupo, cid_capitulo in set(
        zip(
            df_cid["CAT"],
            df_cid["DESCRICAO_CAT"],
            df_cid["GRUPO"],
            df_cid["CAPITULO"],
        )
    )
}

# %%
CBO_FILE_TRANSLATOR = "CBO94 - CBO2002 - Conversao.csv"

df_cbo_tradutor = pd.read_csv(
    data_path / CBO_FILE_TRANSLATOR, sep=";", encoding="latin-1"
)

display(df_cbo_tradutor)

cbo_tradutor_dict = {
    str(cbo94).replace("X", ""): str(cbo2002).zfill(6)
    for cbo94, cbo2002 in zip(df_cbo_tradutor["CBO94"], df_cbo_tradutor["CBO2002"])
}

cbo_tradutor_dict
# Out:
#       CBO94  CBO2002
# 0     X4010    20105
# 1     X4020    20205
# 2     X4030    21105
# 3     X4040    21210
# 4     X5010    10110
# ...     ...      ...
# 1969  98940   782145
# 1970  98945   783225
# 1971  98950   782820
# 1972  99130   516610
# 1973  99150   784205
#
# [1974 rows x 2 columns]
# {'4010': '020105',
#  '4020': '020205',
#  '4030': '021105',
#  '4040': '021210',
#  '5010': '010110',
#  '5020': '010210',
#  '03510': '314110',
#  '03530': '314310',
#  '03540': '314305',
#  '03550': '314115',
#  '03560': '314315',
#  '03570': '314125',
#  '03575': '314120',
#  '03605': '311105',
#  '03615': '301115',
#  '03620': '311205',
#  '03630': '301110',
#  '03640': '301105',
#  '03650': '325115',
#  '03710': '311605',
#  '03720': '311615',
#  '03730': '311625',
#  '03740': '311610',
#  '03750': '311620',
#  '03805': '318005',
#  '03810': '318430',
#  '03820': '318205',
#  '03825': '318310',
#  '03830': '318305',
#  '03835': '318115',
#  '03840': '318420',
#  '03845': '318105',
#  '03850': '318215',
#  '03855': '318110',
#  '03860': '318415',
#  '03865': '318425',
#  '03870': '318405',
#  '03875': '318120',
#  '03880': '318210',
#  '03883': '318015',
#  '03884': '318410',
#  '03885': '318015',
#  '03887': '318010',
#  '03930': '391105',
#  '03935': '391125',
#  '03937': '391220',
#  '03940': '391110',
#  '03945': '351605',
#  '03948': '342120',
#  '03950': '311510',
#  '03960': '311305',
#  '03965': '311515',
#  '03970': '311110',
#  '03975': '351715',
#  '03980': '325205',
#  '03982': '371305',
#  '03983': '371310',
#  '03984': '371305',
#  '03985': '391205',
#  '03987': '351725',
#  '03988': '300305',
#  '03989': '391135',
#  '04120': '215305',
#  '04130': '341105',
#  '04135': '215305',
#  '04140': '215305',
#  '04150': '341115',
#  '04160': '215315',
#  '04170': '215310',
#  '04215': '215115',
#  '04220': '215115',
#  '04230': '215115',
#  '04240': '341215',
#  '04250': '215220',
#  '04315': '215210',
#  '04320': '215205',
#  '04330': '215220',
#  '05110': '221105',
#  '05120': '203025',
#  '05125': '203005',
#  '05130': '203010',
#  '05140': '203015',
#  '05150': '203020',
#  '05230': '223410',
#  '05250': '203015',
#  '05270': '223405',
#  '06310': '223208',
#  '06330': '223272',
#  '06335': '223268',
#  '06340': '223212',
#  '06345': '223240',
#  '06350': '223244',
#  '06355': '223236',
#  '06360': '223256',
#  '06365': '223260',
#  '06370': '223248',
#  '06510': '223305',
#  '06530': '223305',
#  '06540': '223310',
#  '06710': '223405',
#  '06720': '223405',
#  '06810': '223710',
#  '06820': '223710',
#  '06830': '223705',
#  '07110': '223505',
#  '07130': '223560',
#  '07140': '223530',
#  '07145': '223545',
#  '07150': '223520',
#  '07155': '223525',
#  '07160': '223555',
#  '07165': '223550',
#  '07210': '322205',
#  '07215': '322215',
#  '07220': '322210',
#  '07230': '322220',
#  '07310': '251605',
#  '07315': '251605',
#  '07325': '251605',
#  '07345': '251605',
#  '07410': '251510',
#  '07415': '251540',
#  '07425': '251505',
#  '07435': '251510',
#  '07445': '251535',
#  '07450': '251525',
#  '07455': '251515',
#  '07460': '251530',
#  '07525': '223910',
#  '07530': '322305',
#  '07540': '322305',
#  '07620': '223605',
#  '07630': '223905',
#  '07720': '324115',
#  '07730': '324110',
#  '07740': '324105',
#  '07915': '322105',
#  '07925': '223810',
#  '07935': '322405',
#  '07945': '322115',
#  '07950': '322505',
#  '08110': '211205',
#  '08120': '203120',
#  '08130': '211210',
#  '08220': '211115',
#  '08240': '211110',
#  '08250': '211105',
#  '67330': '632120',
#  '70115': '720125',
#  '70120': '810110',
#  '70125': '810105',
#  '70130': '810205',
#  ...}

# %%
input_path = data_path / "CBO2002 - Ocupacao.csv"

df_cbo = pd.read_csv(
    input_path, sep=";", encoding="latin-1", engine="python", on_bad_lines="warn"
)

display(df_cbo)
# Out:
#       CODIGO                                             TITULO
# 0      10105                     Oficial general da aeronáutica
# 1      10110                        Oficial general do exército
# 2      10115                         Oficial general da marinha
# 3      10205                             Oficial da aeronáutica
# 4      10210                                Oficial do exército
# ...      ...                                                ...
# 2714  992205  Encarregado geral de operações de conservação ...
# 2715  992210  Encarregado de equipe de conservação de vias p...
# 2716  992215  Operador de ceifadeira na conservação de vias ...
# 2717  992220  Pedreiro de conservação de vias permanentes (e...
# 2718  992225  Auxiliar geral de conservação de vias permanen...
#
# [2719 rows x 2 columns]

# %%
cbo_dict = {
    str(code): titulo for code, titulo in zip(df_cbo["CODIGO"], df_cbo["TITULO"])
}

for extra_code, titulo in [
    ("999991", "Estudante"),
    ("999992", "Dona de casa"),
    ("999993", "Aposentado"),
    ("999995", "Presidiario"),
]:
    cbo_dict[extra_code] = titulo

# %%
IBGE_FILE = "br_bd_diretorios_brasil_municipio.csv"

df_ibge = pd.read_csv(data_path / IBGE_FILE)

display(df_ibge)
# Out:
#       id_municipio  id_municipio_6  id_municipio_tse  id_municipio_rf  \
# 0          5101837          510183               NaN              NaN
# 1          1100809          110080             477.0            681.0
# 2          1100338          110033             434.0             47.0
# 3          1100205          110020              35.0              3.0
# 4          1101104          110110             493.0            683.0
# ...            ...             ...               ...              ...
# 5566       5209150          520915           92266.0           9799.0
# 5567       5220405          522040           96059.0           9605.0
# 5568       5216304          521630           94552.0           9455.0
# 5569       5218508          521850           95630.0           9563.0
# 5570       5300108          530010           97012.0           9701.0
#
#       id_municipio_bcb                    nome  capital_uf  id_comarca  \
# 0                  NaN  Boa Esperança do Norte         NaN         NaN
# 1              46961.0      Candeias do Jamari         0.0   1100205.0
# 2              44516.0             Nova Mamoré         0.0   1100106.0
# 3              30719.0             Porto Velho         1.0   1100205.0
# 4              46851.0         Itapuã do Oeste         0.0   1100205.0
# ...                ...                     ...         ...         ...
# 5566           43830.0             Gouvelândia         0.0   5218300.0
# 5567           36799.0               São Simão         0.0   5220405.0
# 5568           24550.0            Paranaiguara         0.0   5216304.0
# 5569            4611.0            Quirinópolis         0.0   5218508.0
# 5570           35800.0                Brasília         1.0   5300108.0
#
#       id_regiao_saude nome_regiao_saude  ...  nome_mesorregiao  \
# 0                 NaN               NaN  ...               NaN
# 1             11004.0    Madeira-Mamoré  ...   Madeira-Guaporé
# 2             11004.0    Madeira-Mamoré  ...   Madeira-Guaporé
# 3             11004.0    Madeira-Mamoré  ...   Madeira-Guaporé
# 4             11004.0    Madeira-Mamoré  ...   Madeira-Guaporé
# ...               ...               ...  ...               ...
# 5566          52017.0               Sul  ...        Sul Goiano
# 5567          52015.0        Sudoeste I  ...        Sul Goiano
# 5568          52015.0        Sudoeste I  ...        Sul Goiano
# 5569          52015.0        Sudoeste I  ...        Sul Goiano
# 5570          53001.0  Distrito Federal  ...  Distrito Federal
#
#      id_regiao_metropolitana  \
# 0                        NaN
# 1                        101
# 2                        NaN
# 3                        101
# 4                        NaN
# ...                      ...
# 5566                     NaN
# 5567                     NaN
# 5568                     NaN
# 5569                     NaN
# 5570                    7801
#
#                               nome_regiao_metropolitana   ddd  id_uf sigla_uf  \
# 0                                                   NaN   NaN     51       MT
# 1                   Região Metropolitana de Porto Velho  69.0     11       RO
# 2                                                   NaN  69.0     11       RO
# 3                   Região Metropolitana de Porto Velho  69.0     11       RO
# 4                                                   NaN  69.0     11       RO
# ...                                                 ...   ...    ...      ...
# 5566                                                NaN  64.0     52       GO
# 5567                                                NaN  64.0     52       GO
# 5568                                                NaN  64.0     52       GO
# 5569                                                NaN  64.0     52       GO
# 5570  Região Integrada de Desenvolvimento do Distrit...  61.0     53       DF
#
#                nome_uf   nome_regiao amazonia_legal  \
# 0          Mato Grosso  Centro-Oeste              1
# 1             Rondônia         Norte              1
# 2             Rondônia         Norte              1
# 3             Rondônia         Norte              1
# 4             Rondônia         Norte              1
# ...                ...           ...            ...
# 5566             Goiás  Centro-Oeste              0
# 5567             Goiás  Centro-Oeste              0
# 5568             Goiás  Centro-Oeste              0
# 5569             Goiás  Centro-Oeste              0
# 5570  Distrito Federal  Centro-Oeste              0
#
#                                        centroide
# 0      POINT(-54.9417429754238 -13.463197935201)
# 1     POINT(-63.3254198532114 -8.88702392955617)
# 2     POINT(-64.6295025002404 -10.3822863210755)
# 3     POINT(-64.3041357999869 -9.15394033687075)
# 4      POINT(-63.044960463046 -9.17019402601564)
# ...                                          ...
# 5566   POINT(-50.1557720034523 -18.509097862386)
# 5567  POINT(-50.5908964743097 -19.0104603156912)
# 5568  POINT(-50.6237723254387 -18.8084672995792)
# 5569  POINT(-50.5293403684736 -18.4373825773833)
# 5570   POINT(-47.797310944881 -15.7808447891649)
#
# [5571 rows x 27 columns]

# %%
ibge_dict = {
    str(code): {
        "municipio": municipio,
        "regiao_imediata": regiao_imediata,
        "regiao_intermediaria": regiao_intermediaria,
        "uf": uf,
        "regiao": regiao,
    }
    for code, municipio, regiao_imediata, regiao_intermediaria, uf, regiao in zip(
        df_ibge["id_municipio"],
        df_ibge["nome"],
        df_ibge["nome_regiao_imediata"],
        df_ibge["nome_regiao_intermediaria"],
        df_ibge["sigla_uf"],
        df_ibge["nome_regiao"],
    )
}

ibge_6_dict = {
    str(code): {
        "municipio": municipio,
        "regiao_imediata": regiao_imediata,
        "regiao_intermediaria": regiao_intermediaria,
        "uf": uf,
        "regiao": regiao,
    }
    for code, municipio, regiao_imediata, regiao_intermediaria, uf, regiao in zip(
        df_ibge["id_municipio_6"],
        df_ibge["nome"],
        df_ibge["nome_regiao_imediata"],
        df_ibge["nome_regiao_intermediaria"],
        df_ibge["sigla_uf"],
        df_ibge["nome_regiao"],
    )
}

# %%
df_ibge[df_ibge["nome"] == "Curitiba"]
# Out:
#       id_municipio  id_municipio_6  id_municipio_tse  id_municipio_rf  \
# 4285       4106902          410690           75353.0           7535.0
#
#       id_municipio_bcb      nome  capital_uf  id_comarca  id_regiao_saude  \
# 4285           13853.0  Curitiba         1.0   4106902.0          41002.0
#
#         nome_regiao_saude  ...           nome_mesorregiao  \
# 4285  2ª RS Metropolitana  ...  Metropolitana de Curitiba
#
#      id_regiao_metropolitana         nome_regiao_metropolitana   ddd  id_uf  \
# 4285                    5501  Região Metropolitana de Curitiba  41.0     41
#
#      sigla_uf  nome_uf nome_regiao amazonia_legal  \
# 4285       PR   Paraná         Sul              0
#
#                                       centroide
# 4285  POINT(-49.288257976141 -25.4778625693795)
#
# [1 rows x 27 columns]

# %%
DUCKDB_FILE = "sim.duckdb"

# Filtro de município -> Curitiba, Local de ocorrência -> via pública
con = duckdb.connect(database=data_path / DUCKDB_FILE, read_only=True)
df_sim = con.execute(
    "SELECT * FROM sim WHERE (CODMUNOCOR = '4106902' or CODMUNOCOR = '410690') AND LOCOCOR = '4'"
).fetchdf()
con.close()

df_sim = drop_cols_by_null_percent(df_sim, 0.5, "LINHA", logger)

df_sim
# Out:
# 2025-10-27 18:20:27 - INFO - id 0.00% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:27 - WARNING - CRSOCOR 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:27 - WARNING - OCUPACAO 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:27 - INFO - IDADE 0.51% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:27 - WARNING - PESONASC 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:27 - WARNING - AREARES 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - OCUPPAI 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - FONTINFO 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - DATAREG 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - INSTRUCAO 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - INFO - CAUSABAS 0.00% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - WARNING - FILHVIVOS 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - CODIGO 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - LOCACID 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - INFO - TIPOBITO 0.00% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - WARNING - ACIDTRAB 81.84% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - TIPOACID 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - DATAOBITO 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - OBITOFE2 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - SEMANGEST 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - INFO - NECROPSIA 0.70% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - WARNING - DATANASC 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - INFO - CIRURGIA 41.76% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - WARNING - CRITICA 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - MUNIOCOR 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - TIPOVIOL 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - INFO - SEXO 0.01% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - WARNING - IDADEMAE 97.45% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - INFO - LOCOCOR 0.00% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - WARNING - INSTRMAE 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - CRSRES 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - INSTRPAI 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - REGISTRO 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - OCUPMAE 97.42% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - OBITOFE1 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - INFO - EXAME 41.66% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - WARNING - MUNIRES 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - UFINFORM 67.36% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - INFO - NATURAL 8.65% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - INFO - ATESTANTE 15.96% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - WARNING - FILHMORT 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - TIPOGRAV 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - TIPOPARTO 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - ESTCIVIL 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - INFO - CONTADOR 0.00% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - WARNING - NUMEXPORT 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - INFO - ASSISTMED 12.30% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - INFO - RACACOR 9.57% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - WARNING - ETNIA 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - INFO - CIRCOBITO 13.04% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - WARNING - GRAVIDEZ 97.42% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - PARTO 97.42% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - INFO - FONTE 43.17% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - INFO - DTOBITO 0.00% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - INFO - LINHAII 93.17% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - INFO - CODMUNRES 0.00% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - INFO - CODMUNOCOR 0.00% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - WARNING - ESCMAE 97.44% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - INFO - OCUP 5.01% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - INFO - ESTCIV 3.48% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - WARNING - QTDFILVIVO 97.46% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - INFO - DTNASC 3.86% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - WARNING - OBITOGRAV 93.41% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - INFO - LINHAA 11.42% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - INFO - ESC 10.60% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - INFO - LINHAC 71.12% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - WARNING - QTDFILMORT 97.45% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - OBITOPUERP 93.38% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - INFO - LINHAB 25.47% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - WARNING - GESTACAO 97.45% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - PESO 97.42% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - OBITOPARTO 97.44% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - INFO - LINHAD 91.97% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - WARNING - CODESTAB 97.51% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - CB_PRE 73.27% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - INFO - DTINVESTIG 48.15% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - INFO - DTRECEBIM 35.36% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - WARNING - TPASSINA 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - INFO - FONTEINV 46.33% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - INFO - DTCADASTRO 30.36% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - INFO - TPPOS 31.93% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - INFO - CAUSABAS_O 30.36% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - INFO - DTATESTADO 30.36% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - INFO - HORAOBITO 31.36% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - WARNING - TPOBITOCOR 93.82% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - MORTEPARTO 97.48% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - INFO - ORIGEM 49.11% nulos < limite 50.00%: APROVADO
# 2025-10-27 18:20:28 - WARNING - DTCADINF 97.48% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - DTCADINV 94.16% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - ESC2010 60.51% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - STDOEPIDEM 54.61% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - DTRECORIG 91.18% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - CAUSAMAT 97.51% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - COMUNSVOIM 63.80% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - STDONOVA 54.61% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - ESCMAE2010 97.49% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - DTRECORIGA 58.49% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - ESCFALAGR1 68.14% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - SERIESCFAL 77.18% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - CODMUNCART 96.38% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - DTCONCASO 97.51% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - DTCONINV 95.27% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - DTREGCART 96.38% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - TPMORTEOCO 94.92% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - NUMREGCART 96.38% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - EXPDIFDATA 99.99% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - NUDIASOBIN 98.98% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - ESCMAEAGR1 97.49% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - SERIESCMAE 97.51% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - SEMAGESTAC 97.51% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - DIFDATA 59.55% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - ESTABDESCR 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - STCODIFICA 67.56% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - CODMUNNATU 68.06% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - VERSAOSCB 83.32% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - NUDIASOBCO 95.56% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - VERSAOSIST 67.56% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - CODIFICADO 67.56% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - ALTCAUSA 97.49% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - TPRESGINFO 97.44% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - NUDIASINF 100.00% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - NUMEROLOTE 67.56% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - TPNIVELINV 95.55% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - FONTES 96.93% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - FONTESINF 96.32% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - ATESTADO 67.56% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - OPOR_DO 95.23% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - CB_ALT 97.51% nulos >= limite 50.00% REPROVADO
# 2025-10-27 18:20:28 - WARNING - TP_ALTERA 97.51% nulos >= limite 50.00% REPROVADO
#              id IDADE CAUSABAS TIPOBITO NECROPSIA CIRURGIA SEXO LOCOCOR EXAME  \
# 0      13706772   427     V892        2         1        2    1       4     2
# 1      14043004   451      R98        2      None     None    1       4  None
# 2      14047392   455      I64        2         2        2    2       4     1
# 3      14047656   422     X954        2         1        2    1       4     2
# 4      14047660   429     V892        2         1        2    1       4     2
# ...         ...   ...      ...      ...       ...      ...  ...     ...   ...
# 12184  47748975   446      R99        2         1             1       4
# 12185  47748978   429     V051        2         1             1       4
# 12186  47748992   435     Y244        2         1             1       4
# 12187  47749654   470     I802        2         2             1       4
# 12188  47750321   474     I461        2         2             1       4
#
#       NATURAL  ... LINHAD DTINVESTIG DTRECEBIM FONTEINV DTCADASTRO TPPOS  \
# 0         852  ...   None       None      None     None       None  None
# 1         800  ...   None       None      None     None       None  None
# 2         841  ...   None       None      None     None       None  None
# 3         833  ...   None       None      None     None       None  None
# 4         800  ...   None       None      None     None       None  None
# ...       ...  ...    ...        ...       ...      ...        ...   ...
# 12184     841  ...                    23092024            20092024     N
# 12185     841  ...                    03102024            03102024     N
# 12186     841  ...                    23092024            20092024     N
# 12187     841  ...          24102024  29102024        8   27092024     S
# 12188     841  ...                    09122024            04122024     N
#
#       CAUSABAS_O DTATESTADO HORAOBITO ORIGEM
# 0           None       None      None   None
# 1           None       None      None   None
# 2           None       None      None   None
# 3           None       None      None   None
# 4           None       None      None   None
# ...          ...        ...       ...    ...
# 12184        R99   15092024      1730      1
# 12185       V051   15092024      0300      1
# 12186       Y244   18092024      0900      1
# 12187       I802   25092024      1730      1
# 12188       I461   09112024      1255      1
#
# [12189 rows x 37 columns]

# %%
df_sim.head()
# Out:
#          id IDADE CAUSABAS TIPOBITO NECROPSIA CIRURGIA SEXO LOCOCOR EXAME  \
# 0  13706772   427     V892        2         1        2    1       4     2
# 1  14043004   451      R98        2      None     None    1       4  None
# 2  14047392   455      I64        2         2        2    2       4     1
# 3  14047656   422     X954        2         1        2    1       4     2
# 4  14047660   429     V892        2         1        2    1       4     2
#
#   NATURAL  ... LINHAD DTINVESTIG DTRECEBIM FONTEINV DTCADASTRO TPPOS  \
# 0     852  ...   None       None      None     None       None  None
# 1     800  ...   None       None      None     None       None  None
# 2     841  ...   None       None      None     None       None  None
# 3     833  ...   None       None      None     None       None  None
# 4     800  ...   None       None      None     None       None  None
#
#   CAUSABAS_O DTATESTADO HORAOBITO ORIGEM
# 0       None       None      None   None
# 1       None       None      None   None
# 2       None       None      None   None
# 3       None       None      None   None
# 4       None       None      None   None
#
# [5 rows x 37 columns]

# %% [markdown]
# <h2>Dicionário de Dados</h2>
# <table border="1" cellspacing="0" cellpadding="5">
#   <thead>
#     <tr>
#       <th>Nome Original</th>
#       <th>Nome Normalizado</th>
#       <th>Categoria</th>
#       <th>Observações</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr><td>CONTADOR</td><td>contador</td><td>Metadado</td><td></td></tr>
#     <tr><td>ORIGEM</td><td>origem</td><td>Metadado</td><td>1 – Oracle; 2 – Banco estadual via FTP; 3 – Banco SEADE; 9 – Ignorado</td></tr>
#     <tr><td>DTNASC</td><td>data_nascimento</td><td>Falecido</td><td>ddmmaaaa</td></tr>
#     <tr><td>IDADE</td><td>idade</td><td>Falecido</td><td>O primeiro dígito indica a unidade da idade (1=minuto, 2=hora, 3=mês, 4=ano, 5&gt;100 anos); o segundo dígito indica a quantidade de unidades</td></tr>
#     <tr><td>NATURAL</td><td>naturalidade</td><td>Falecido</td><td></td></tr>
#     <tr><td>CODMUNRES</td><td>municipio_residencia</td><td>Falecido</td><td>Código IBGE</td></tr>
#     <tr><td>SEXO</td><td>sexo</td><td>Falecido</td><td>1 – masculino; 2 – feminino</td></tr>
#     <tr><td>RACACOR</td><td>raca_cor</td><td>Falecido</td><td>1 – Branca; 2 – Preta; 3 – Amarela; 4 – Parda; 5 – Indígena</td></tr>
#     <tr><td>ESTCIV</td><td>situacao_conjugal</td><td>Falecido</td><td>1 – Solteiro; 2 – Casado; 3 – Viúvo; 4 – Separado/divorciado; 5 – União estável; 9 – Ignorado</td></tr>
#     <tr><td>ESC</td><td>escolaridade_em_anos</td><td>Falecido</td><td>1 – Nenhuma; 2 – 1 a 3 anos; 3 – 4 a 7 anos; 4 – 8 a 11 anos; 5 – 12 anos ou mais; 9 – Ignorado</td></tr>
#     <tr><td>OCUP</td><td>ocupacao</td><td>Falecido</td><td>CBO 2002</td></tr>
#     <tr><td>DTOBITO</td><td>data_obito</td><td>Óbito</td><td>ddmmaaaa</td></tr>
#     <tr><td>HORAOBITO</td><td>hora_obito</td><td>Óbito</td><td>hhmm</td></tr>
#     <tr><td>LOCOCOR</td><td>local_obito</td><td>Óbito</td><td>1 – hospital; 2 – outros estabelecimentos; 3 – domicílio; 4 – via pública; 5 – outros; 6 – aldeia indígena; 9 – ignorado</td></tr>
#     <tr><td>CODMUNOCOR</td><td>municipio_obito</td><td>Óbito</td><td>Código IBGE</td></tr>
#     <tr><td>CODEESTAB</td><td>estabelecimento</td><td>Óbito</td><td>CNES</td></tr>
#     <tr><td>CAUSABAS</td><td>causa_obito</td><td>Óbito</td><td>CID-10</td></tr>
#     <tr><td>CAUSABAS_O</td><td>causa_obito_origem</td><td>Óbito</td><td>CID-10</td></tr>
#     <tr><td>LINHAA</td><td>causas_obito_1a</td><td>Óbito</td><td>CID-10</td></tr>
#     <tr><td>LINHAB</td><td>causas_obito_1b</td><td>Óbito</td><td>CID-10</td></tr>
#     <tr><td>LINHAC</td><td>causas_obito_1c</td><td>Óbito</td><td>CID-10</td></tr>
#     <tr><td>LINHAD</td><td>causas_obito_1d</td><td>Óbito</td><td>CID-10</td></tr>
#     <tr><td>LINHAII</td><td>causas_obito_2</td><td>Óbito</td><td>CID-10</td></tr>
#     <tr><td>ASSISTMED</td><td>recebeu_assistencia_medica</td><td>Óbito</td><td>1 – sim; 2 – não; 9 – ignorado</td></tr>
#     <tr><td>EXAME</td><td>realizacao_de_exame</td><td>Óbito</td><td>1 – sim; 2 – não; 9 – ignorado</td></tr>
#     <tr><td>CIRURGIA</td><td>realizacao_de_cirurgia</td><td>Óbito</td><td>1 – sim; 2 – não; 9 – ignorado</td></tr>
#     <tr><td>TIPOBITO</td><td>obito_fetal</td><td>Óbito</td><td>1 – Fetal; 2 – Não fetal</td></tr>
#     <tr><td>NECROPSIA</td><td>necropsia</td><td>Post-mortem</td><td>1 – sim; 2 – não; 9 – ignorado</td></tr>
#     <tr><td>TPPOS</td><td>investigado</td><td>Post-mortem</td><td>S – sim; N – não</td></tr>
#     <tr><td>DTATESTADO</td><td>data_atestado</td><td>Post-mortem</td><td>ddmmaaaa</td></tr>
#     <tr><td>DTCADASTRO</td><td>data_cadastro</td><td>Post-mortem</td><td>ddmmaaaa</td></tr>
#     <tr><td>DTRECEBIM</td><td>data_recebimento</td><td>Post-mortem</td><td>ddmmaaaa</td></tr>
#     <tr><td>ATESTANTE</td><td>atestante</td><td>Post-mortem</td><td>1 – Assistente; 2 – Substituto; 3 – IML; 4 – SVO; 5 – Outro</td></tr>
#   </tbody>
# </table>

# %%
# traduzir colunas
df_col_dict = {
    # metadado
    "CONTADOR": "contador",
    "ORIGEM": "origem",
    # falecido
    "DTNASC": "data_nascimento",
    "IDADE": "idade",
    "NATURAL": "naturalidade",
    "CODMUNRES": "municipio_residencia",
    "SEXO": "sexo",
    "RACACOR": "raca_cor",
    "ESTCIV": "situacao_conjugal",
    "ESC": "escolaridade_em_anos",
    "OCUP": "ocupacao",
    # falecimento
    "DTOBITO": "data_obito",
    "HORAOBITO": "hora_obito",
    "LOCOCOR": "local_obito",
    "CODMUNOCOR": "municipio_obito",
    "CAUSABAS": "causa_obito",
    "CAUSABAS_O": "causa_obito_origem",
    "LINHAA": "causas_obito_1a",
    "LINHAB": "causas_obito_1b",
    "LINHAC": "causas_obito_1c",
    "LINHAD": "causas_obito_1d",
    "LINHAII": "causas_obito_2",
    "ASSISTMED": "recebeu_assistencia_medica",
    "EXAME": "realizacao_de_exame",
    "CIRURGIA": "realizacao_de_cirurgia",
    "TIPOBITO": "obito_fetal",
    # post-mortem
    "NECROPSIA": "necropsia",
    "TPPOS": "investigado",
    "DTATESTADO": "data_atestado",
    "DTCADASTRO": "data_cadastro",  # ddmmaaaa
    "DTRECEBIM": "data_recebimento",  # ddmmaaaa
    "ATESTANTE": "atestante",
}

df_sim_mapped = df_sim.rename(columns=df_col_dict)
df_sim_mapped = df_sim_mapped[list(df_col_dict.values())]

# %%
# 'contador' indica o número do óbito no ano; como o dataset já foi filtrado, não acrescenta informação relevante.
df_sim_mapped = df_sim_mapped.drop(columns="contador")

# A coluna 'naturalidade' utiliza um código municipal distinto das demais e não pôde ser decodificada.
df_sim_mapped = df_sim_mapped.drop(columns=["naturalidade"])

# As colunas 'causas_obito_*' são listas de causas, e por simplificação foram removidas.
for col in [c for c in df_sim_mapped.columns if c.startswith("causas_obito_")]:
    df_sim_mapped = df_sim_mapped.drop(columns=col)

# %%
for col in [c for c in df_sim_mapped.columns if c.startswith("data_")]:
    df_sim_mapped[col] = pd.to_datetime(
        df_sim_mapped[col], format="%d%m%Y", errors="coerce"
    )

for col in [c for c in df_sim_mapped.columns if c.startswith("hora_")]:
    df_sim_mapped[col] = pd.to_datetime(
        df_sim_mapped[col], format="%H%M", errors="coerce"
    ).dt.time

# %%
for col in [c for c in df_sim_mapped.columns if c.startswith("municipio_")]:
    mapped = (
        df_sim_mapped[col]
        .astype(str)
        .map(ibge_dict)
        .fillna(df_sim_mapped[col].map(ibge_6_dict))
    )

    df_exploded = pd.json_normalize(mapped).add_prefix(f"{col}_")
    df_sim_mapped = pd.concat([df_sim_mapped, df_exploded], axis=1)

# %%
for col in [c for c in df_sim_mapped.columns if c.startswith("causa_obito")]:
    mapped = [
        cid_dict_categoria.get(cid[:3], cid)
        if cid and (cid.endswith("X") or len(cid) == 3)
        else cid_dict_subcategoria.get(cid, cid)
        for cid in df_sim_mapped[col]
    ]

    df_exploded = pd.json_normalize(mapped).add_prefix(f"{col}_")
    df_sim_mapped = pd.concat([df_sim_mapped, df_exploded], axis=1)

# %%
df_sim_mapped["ocupacao"] = (
    df_sim_mapped["ocupacao"]
    .str.zfill(5)
    .map(cbo_tradutor_dict)
    .fillna(df_sim_mapped["ocupacao"])
)


mapped = (
    df_sim_mapped["ocupacao"]
    .str.zfill(6)
    .map(cbo_dict)
    .fillna(df_sim_mapped["ocupacao"])
)

df_exploded = pd.json_normalize(mapped).add_prefix("ocupacao_")
df_sim_mapped = pd.concat([df_sim_mapped, df_exploded], axis=1)

# %%
origem_dict = {"1": "oracle", "2": "banco_estadual", "3": "seade", "9": "ignorado"}

df_sim_mapped["origem"] = (
    df_sim_mapped["origem"].map(origem_dict).fillna(df_sim_mapped["origem"])
)

# %%
unidade_idade_dict = {
    "1": "minuto",
    "2": "hora",
    "3": "mes",
    "4": "ano",
    "5": "maior_100_anos",
}

idade_str = df_sim_mapped["idade"].astype(str).replace("nan", np.nan)
df_sim_mapped["unidade_idade"] = idade_str.str[0].map(unidade_idade_dict)
idade_val = idade_str.str[1:]
df_sim_mapped["idade"] = pd.to_numeric(idade_val, errors="coerce")

# %%
sexo_dict = {
    "1": "masculino",
    "2": "feminino",
}

df_sim_mapped["sexo"] = (
    df_sim_mapped["sexo"]
    .map(sexo_dict)
    .fillna(df_sim_mapped["sexo"])
    .fillna(df_sim_mapped["sexo"])
)

# %%
raca_cor_dict = {
    "1": "branca",
    "2": "preta",
    "3": "amarela",
    "4": "parda",
    "5": "indigena",
}

df_sim_mapped["raca_cor"] = (
    df_sim_mapped["raca_cor"]
    .map(raca_cor_dict, na_action="ignore")
    .fillna(df_sim_mapped["raca_cor"])
)

# %%
estciv_dict = {
    "1": "solteiro",
    "2": "casado",
    "3": "viuvo",
    "4": "separado_judicialmente_divorciado",
    "5": "uniao_estavel",
    "9": "ignorado",
}

df_sim_mapped["situacao_conjugal"] = (
    df_sim_mapped["situacao_conjugal"]
    .map(estciv_dict, na_action="ignore")
    .fillna(df_sim_mapped["situacao_conjugal"])
)

# %%
esc_dict = {
    "1": "nenhuma",
    "2": "de_1_a_3_anos",
    "3": "de_4_a_7_anos",
    "4": "de_8_a_11_anos",
    "5": "de_12_anos_e_mais",
    "9": "ignorado",
}

df_sim_mapped["escolaridade_em_anos"] = (
    df_sim_mapped["escolaridade_em_anos"]
    .map(esc_dict, na_action="ignore")
    .fillna(df_sim_mapped["escolaridade_em_anos"])
)

# %%
local_obito_dict = {
    "1": "hospital",
    "2": "outros_estabelecimentos_de_saude",
    "3": "domicilio",
    "4": "via_publica",
    "5": "outros",
    "6": "aldeia_indigena",
    "9": "ignorado",
}

df_sim_mapped["local_obito"] = (
    df_sim_mapped["local_obito"]
    .map(local_obito_dict, na_action="ignore")
    .fillna(df_sim_mapped["local_obito"])
)

# como está filtrada na busca, todas as ocorrências são "via pública"
df_sim_mapped.drop(columns=["local_obito"], inplace=True)

# %%
sim_nao_ignorado_dict = {
    "1": "sim",
    "2": "nao",
    "9": "ignorado",
}

for col in [
    "recebeu_assistencia_medica",
    "realizacao_de_exame",
    "realizacao_de_cirurgia",
    "necropsia",
]:
    df_sim_mapped[col] = (
        df_sim_mapped[col]
        .map(sim_nao_ignorado_dict, na_action="ignore")
        .fillna(df_sim_mapped[col])
    )

s_n_dict = {"S": "sim", "N": "nao"}

df_sim_mapped["investigado"] = (
    df_sim_mapped["investigado"]
    .map(s_n_dict, na_action="ignore")
    .fillna(df_sim_mapped["investigado"])
)

# %%
obito_fetal_dict = {
    "1": "fetal",
    "2": "nao_fetal",
}

df_sim_mapped["obito_fetal"] = (
    df_sim_mapped["obito_fetal"]
    .map(obito_fetal_dict, na_action="ignore")
    .fillna(df_sim_mapped["obito_fetal"])
)

# %%
atestante_dict = {
    "1": "assistente",
    "2": "substituto",
    "3": "iml",
    "4": "svo",
    "5": "outro",
}

df_sim_mapped["atestante"] = (
    df_sim_mapped["atestante"]
    .map(atestante_dict, na_action="ignore")
    .fillna(df_sim_mapped["atestante"])
)

# %%
display(df_sim_mapped.obito_fetal.value_counts())

# 'obito_fetal' contém apenas uma categoria após o filtro por município.
df_sim_mapped = df_sim_mapped.drop(columns=["obito_fetal"])
# Out:
# obito_fetal
# nao_fetal    12189
# Name: count, dtype: int64

# %%
df_sim_mapped = df_sim_mapped.replace("", None)

# %%
dataset_path = Path("./dataset/")

df_sim_mapped.to_csv(dataset_path / "curitiba_via_publica.csv", index=False)
